# %%
import pandas as pd
import datetime

# %%
hhs_url = 'https://healthdata.gov/sites/default/files/reported_hospital_capacity_admissions_facility-level_weekly_average_timeseries_20201207.csv'

# %%
hhs_df = pd.read_csv(hhs_url)

# %%
hhs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87369 entries, 0 to 87368
# Data columns (total 93 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   hospital_pk                                                                         87369 non-null  object
#  1   collection_week                                                                     87369 non-null  object
#  2   state                                                                               87369 non-null  object
#  3   ccn                                                                                 86985 non-null  object
#  4   hospital_name                                                                       87369 non-null  object
# ...

# %%
hhs_df = hhs_df.replace([-999999.0], 1)

# %%
hhs_df.to_csv('HHSData.csv', index=False)

# %%
hhs_df.head(10)
# Out:
#                                          hospital_pk collection_week state  \
# 0  aab2bb3ab769da90baf57242c96ec481afb5ec6a233784...      2020-11-27    LA
# 1  36db6bad3679dfdcccc301fc608438109ad907943c702f...      2020-11-27    PR
# 2  976b4ce7c95e1cd394112ce7762ed040f18a141e56a52e...      2020-11-27    PR
# 3  ee04edd185865c38c839812cb2eb5ae5d3f8922e3b629e...      2020-11-27    LA
# 4  f70d7abf93c78280583ac18e896e6737cca8212b017513...      2020-11-27    NV
# 5  ff9032c172057190bf52f523d253c79af2d5f74d007084...      2020-11-27    PR
# 6                                             452193      2020-11-27    TX
# 7  3b081d5ef1c552538e4af4aa593a857bb922a4f364a412...      2020-11-27    LA
# 8  df2363988746840134806aa7b2accf9c89259601776986...      2020-11-27    PR
# 9  9922a3f069ff4686fe467885206fb1172f609233cfe517...      2020-11-27    PR
#
#       ccn                          hospital_name  \
# 0     NaN          Crescent City Surgical Centre
# ...
