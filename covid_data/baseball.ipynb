# %%
from pybaseball import statcast

# %%
data = statcast()
# Out:
# start_dt 2021-04-01
# end_dt 2021-04-02
# ...
# This is a large query, it may take a moment to complete
# 100%|██████████| 2/2 [00:03<00:00,  1.99s/it]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4148 entries, 3114 to 4073
# Data columns (total 92 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pitch_type                       4148 non-null   object
#  1   game_date                        4148 non-null   datetime64[ns]
#  2   release_speed                    4148 non-null   float64
#  3   release_pos_x                    4148 non-null   float64
#  4   release_pos_z                    4148 non-null   float64
#  5   player_name                      4148 non-null   object
#  6   batter                           4148 non-null   Int64
#  7   pitcher                          4148 non-null   Int64
#  8   events                           1055 non-null   object
#  9   description                      4148 non-null   object
#  10  spin_dir                         0 non-null      Int64
# ...

# %%
data.to_csv('today.csv', index=False)

# %%
data.tail()
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3797         FF 2017-06-24           91.8          -1.73           6.55
# 3877         FS 2017-06-24           82.6          -1.73           6.38
# 4065         SL 2017-06-24           85.9          -1.63           6.37
# 4178         FF 2017-06-24           91.9          -1.47           6.59
# 4308         FF 2017-06-24           92.4          -1.57           6.57
#
#       player_name  batter  pitcher     events      description  ...  \
# 3797  Faria, Jake  452234   607188  field_out    hit_into_play  ...
# 3877  Faria, Jake  452234   607188        NaN             ball  ...
# 4065  Faria, Jake  452234   607188        NaN  swinging_strike  ...
# 4178  Faria, Jake  452234   607188        NaN    called_strike  ...
# 4308  Faria, Jake  452234   607188        NaN             ball  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# ...
